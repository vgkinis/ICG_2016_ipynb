# %%
import sys
sys.path.append("/Users/vasilis/")
from IPython.display import Image
from IPython.display import Latex
import vaspy
from matplotlib import pyplot as plt
plt.ion()

# %% [markdown]
# jupyter nbconvert ICG_2016_isotopes_notes.ipynb --to slides --post serve

# %% [markdown]
# # Observed Isotope Effects in Precipitation

# %% [markdown]
# ## Latitude - Annual temperature Effect
# * Formation of atmospheric vapor
# * Progressive condensation to higher latitudes.
# * $\delta^{18}\text{O} = -0.6$ per mile / degree of latitude

# %%
Image("../figs/Dansgaard_slope.png", width = 500)

# %% [markdown]
# Dansgaard 1964

# %% [markdown]
# ## Seasonal Effect
#
# ### A consequence of changing temperatures but not as strong as the latitude effect
#
# An example from a shallow ice core from South Greenland

# %%
Image("../figs/sdome_syttensen.png", width = 900)

# %% [markdown]
# ## Elevation effect

# %% [markdown]
# ## Climate Variations

# %%
Image("../figs/neem_bags_d18.png", width = 900)
